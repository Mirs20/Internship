# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,f_classif
  
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel(r"C:\Users\A\Documents\flip robo\worksheet fro fliprobo\Customer_retention_dataset\customer_retention_dataset.xlsx",sheet_name=0)

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
data=pd.read_excel(r"C:\Users\A\Documents\flip robo\worksheet fro fliprobo\Customer_retention_dataset\customer_retention_dataset.xlsx",sheet_name=1)
data.shape
# Out:
# (269, 71)

# %%
data.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# 1Gender of respondent
# 2 How old are you?
# 3 Which city do you shop online from?
# 4 What is the Pin Code of where you shop online from?
# 5 Since How Long You are Shopping Online ?
# 6 How many times you have made an online purchase in the past 1 year?
# 7 How do you access the internet while shopping on-line?
# 8 Which device do you use to access the online shopping?
# 9 What is the screen size of your mobile device?
# 10 What is the operating system (OS) of your device?
# 11 What browser do you run on your device to access the website?
# 12 Which channel did you follow to arrive at your favorite online store for the first time?
# 13 After first visit, how do you reach the online retail store?
# 14 How much time do you explore the e- retail store before making a purchase decision?
# 15 What is your preferred payment Option?
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?
# ...

# %% [markdown]
# 1Gender of respondent
#
# 2 How old are you?
#
# 3 Which city do you shop online from?
#
# 4 What is the Pin Code of where you shop online from?
#
# 5 Since How Long You are Shopping Online ?
#
# 6 How many times you have made an online purchase in the past 1 year?
#
# 7 How do you access the internet while shopping on-line?
#
# 8 Which device do you use to access the online shopping?
#
# 15 What is your preferred payment Option?
#
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?
# 17 Why did you abandon the “Bag”, “Shopping Cart”?
# 18 The content on the website must be easy to read and understand
# 19 Information on similar product to the one highlighted  is important for product comparison
# 20 Complete information on listed seller and product being offered is important for purchase decision.
# 21 All relevant information on listed products must be stated clearly
#
# 23 Loading and processing speed
# 24 User friendly Interface of the website
# 25 Convenient Payment methods
# 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time
#
# 30 Online shopping gives monetary benefit and discounts
#
# 32 Shopping online is convenient and flexible
# 33 Return and replacement policy of the e-tailer is important for purchase decision
#
# 41 Monetary savings
#
# 47 Getting value for money spent

# %%
for i in df.columns[:48]:
    print(i,":\n")
    print(len(df[i].unique()))
    print('______________________________\n')
# Out:
# 1Gender of respondent :
#
# 2
# ______________________________
#
# 2 How old are you?  :
#
# 5
# ______________________________
#
# 3 Which city do you shop online from? :
#
# 11
# ______________________________
#
# 4 What is the Pin Code of where you shop online from? :
#
# 39
# ______________________________
#
# 5 Since How Long You are Shopping Online ? :
#
# 5
# ______________________________
#
# 6 How many times you have made an online purchase in the past 1 year? :
#
# 6
# ______________________________
#
# 7 How do you access the internet while shopping on-line? :
#
# 4
# ______________________________
#
# 8 Which device do you use to access the online shopping? :
#
# 4
# ______________________________
#
# 9 What is the screen size of your mobile device?						                                         :
#
# 4
# ______________________________
#
# 10 What is the operating system (OS) of your device?				                                           :
#
# 3
# ...

# %%
for i in df.columns[:48]:
    print(i,"\n")
    print(df[i].unique())
    print('----------------------------------\n')
    print(df[i].value_counts(),'\n')
    print('----------------------------------\n')
# Out:
# 1Gender of respondent
#
# ['Male' 'Female']
# ----------------------------------
#
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
#
# ----------------------------------
#
# 2 How old are you?
#
# ['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
# ----------------------------------
#
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
#
# ----------------------------------
#
# 3 Which city do you shop online from?
#
# ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# ----------------------------------
#
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# ...

# %%
num1=[]
obj1=[]
for i in data.columns[:48]:
    if data[i].dtype==np.object:
        obj1.append(i)
    else:
        num1.append(i)
print('Number of Numeric variables :',len(num1),'\n')
print(num1)
print("--------------------------")
print('Number of Objective  variables :',len(obj1),'\n')
print(obj1)
# Out:
# Number of Numeric variables : 46
#
# ...

# %%
num=[]
obj=[]
for i in df.columns[:48]:
    if df[i].dtype==np.object:
        obj.append(i)
    else:
        num.append(i)
print('Number of Numeric variables :',len(num),'\n')
print(num)
print("--------------------------")
print('Number of Objective  variables :',len(obj),'\n')
print(obj)
# Out:
# Number of Numeric variables : 1
#
# ['4 What is the Pin Code of where you shop online from?']
# --------------------------
# Number of Objective  variables : 47
#
# ...

# %%
df.drop('4 What is the Pin Code of where you shop online from?',axis=1,inplace=True)

# %%
df['7 How do you access the internet while shopping on-line?'].replace('Mobile internet','Mobile Internet',inplace=True)

# %%
plt.figure(figsize=(15,80))
sns.set_palette('Set1')
graph=1

for column in obj[:10]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(x=df[column])
        plt.xlabel(column,fontsize=20)
        plt.xticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,80))
sns.set_palette('Set1')
graph=1

for column in obj[10:20]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(x=df[column])
        plt.xlabel(column,fontsize=20)
        plt.xticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,80))
sns.set_palette('Set1')
graph=1

for column in obj[20:30]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(x=df[column])
        plt.xlabel(column,fontsize=15)
        plt.xticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,80))
sns.set_palette('Set1')
graph=1

for column in obj[30:40]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(x=df[column])
        plt.xlabel(column,fontsize=15)
        plt.xticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,200))
sns.set_palette('Set1')
graph=1

for column in obj[40:50]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(y=df[column])
        plt.ylabel(column,fontsize=15)
        plt.yticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,200))
sns.set_palette('Set1')
graph=1

for column in obj[50:60]:
    if graph<=len(obj):
        ax=plt.subplot(10,1,graph)
        sns.countplot(y=df[column])
        plt.ylabel(column,fontsize=15)
        plt.yticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(15,200))
sns.set_palette('Set1')
graph=1

for column in obj[60:71]:
    if graph<=len(obj):
        ax=plt.subplot(11,1,graph)
        sns.countplot(y=df[column])
        plt.ylabel(column,fontsize=15)
        plt.yticks(fontsize=10)
    graph+=1
plt.show()
plt.tight_layout()

# %%
cor=data.corr().abs()

# %%
fig1=plt.figure(figsize=(40,40))
sns.heatmap(cor[(cor>=0.7)&(cor<0.8)],mask=np.triu(np.ones_like(cor, dtype=bool)),annot=True,cmap='Accent')
plt.xticks(fontsize=10,rotation='90')
plt.yticks(fontsize=10)
plt.title("Correlation Matrix")
fig1.savefig('Flip CorrelationCustomer retention.jpeg')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['25 Convenient Payment methods'],x=df['24 User friendly Interface of the website'])
plt.ylabel('25 Convenient Payment methods',fontsize=20)
plt.xlabel('24 User friendly Interface of the website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['21 All relevant information on listed products must be stated clearly'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('21 All relevant information on listed products must be stated clearly',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['22 Ease of navigation in website'],x=df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.ylabel('22 Ease of navigation in website',fontsize=20)
plt.xlabel('19 Information on similar product to the one highlighted  is important for product comparison',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['21 All relevant information on listed products must be stated clearly'],x=df['22 Ease of navigation in website'])
plt.ylabel('21 All relevant information on listed products must be stated clearly',fontsize=20)
plt.xlabel('22 Ease of navigation in website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['24 User friendly Interface of the website'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('24 User friendly Interface of the website',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['24 User friendly Interface of the website'],x=df['22 Ease of navigation in website'])
plt.ylabel('24 User friendly Interface of the website',fontsize=20)
plt.xlabel('22 Ease of navigation in website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['24 User friendly Interface of the website'],x=df['23 Loading and processing speed'])
plt.ylabel('24 User friendly Interface of the website',fontsize=20)
plt.xlabel('23 Loading and processing speed',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['25 Convenient Payment methods'],x=df['23 Loading and processing speed'])
plt.ylabel('25 Convenient Payment methods',fontsize=20)
plt.xlabel('23 Loading and processing speed',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['25 Convenient Payment methods'],x=df['23 Loading and processing speed'])
plt.ylabel('25 Convenient Payment methods',fontsize=20)
plt.xlabel('24 User friendly Interface of the website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'],x=df['23 Loading and processing speed'])
plt.ylabel('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',fontsize=20)
plt.xlabel('23 Loading and processing speed',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['27 Empathy (readiness to assist with queries) towards the customers'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['27 Empathy (readiness to assist with queries) towards the customers'],x=df['21 All relevant information on listed products must be stated clearly'])
plt.ylabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.xlabel('21 All relevant information on listed products must be stated clearly',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['27 Empathy (readiness to assist with queries) towards the customers'],x=df['22 Ease of navigation in website'])
plt.ylabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.xlabel('22 Ease of navigation in website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['27 Empathy (readiness to assist with queries) towards the customers'],x=df['24 User friendly Interface of the website'])
plt.ylabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.xlabel('24 User friendly Interface of the website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['31 Enjoyment is derived from shopping online'],x=df['30 Online shopping gives monetary benefit and discounts'])
plt.ylabel('31 Enjoyment is derived from shopping online',fontsize=20)
plt.xlabel('30 Online shopping gives monetary benefit and discounts',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['31 Enjoyment is derived from shopping online'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('38 User satisfaction cannot exist without trust',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['35 Displaying quality Information on the website improves satisfaction of customers'],x=df['32 Shopping online is convenient and flexible'])
plt.ylabel('35 Displaying quality Information on the website improves satisfaction of customers',fontsize=20)
plt.xlabel('32 Shopping online is convenient and flexible',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['38 User satisfaction cannot exist without trust'],x=df['27 Empathy (readiness to assist with queries) towards the customers'])
plt.ylabel('38 User satisfaction cannot exist without trust',fontsize=20)
plt.xlabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['38 User satisfaction cannot exist without trust'],x=df['21 All relevant information on listed products must be stated clearly'])
plt.ylabel('38 User satisfaction cannot exist without trust',fontsize=20)
plt.xlabel('21 All relevant information on listed products must be stated clearly',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
# Correlation between 0.7 to 0.80

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['8 Which device do you use to access the online shopping?'],x=df[df.columns[7]])
plt.ylabel('8 Which device do you use to access the online shopping?',fontsize=20)
plt.xlabel('9 What is the screen size of your mobile device?',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['20 Complete information on listed seller and product being offered is important for purchase decision.'],x=df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.ylabel('20 Complete information on listed seller and product being offered is important for purchase decision.',fontsize=20)
plt.xlabel('19 Information on similar product to the one highlighted  is important for product comparison',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['22 Ease of navigation in website'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('22 Ease of navigation in website',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['22 Ease of navigation in website'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('22 Ease of navigation in website',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['24 User friendly Interface of the website'],x=df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.ylabel('24 User friendly Interface of the website',fontsize=20)
plt.xlabel('19 Information on similar product to the one highlighted  is important for product comparison',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['24 User friendly Interface of the website'],x=df['21 All relevant information on listed products must be stated clearly'])
plt.ylabel('24 User friendly Interface of the website',fontsize=20)
plt.xlabel('21 All relevant information on listed products must be stated clearly',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['25 Convenient Payment methods'],x=df['18 The content on the website must be easy to read and understand'])
plt.ylabel('25 Convenient Payment methods',fontsize=20)
plt.xlabel('18 The content on the website must be easy to read and understand',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'],x=df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.ylabel('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',fontsize=20)
plt.xlabel('19 Information on similar product to the one highlighted  is important for product comparison',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['28 Being able to guarantee the privacy of the customer'],x=df['22 Ease of navigation in website'])
plt.ylabel('28 Being able to guarantee the privacy of the customer',fontsize=20)
plt.xlabel('22 Ease of navigation in website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['28 Being able to guarantee the privacy of the customer'],x=df['24 User friendly Interface of the website'])
plt.ylabel('28 Being able to guarantee the privacy of the customer',fontsize=20)
plt.xlabel('24 User friendly Interface of the website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['28 Being able to guarantee the privacy of the customer'],x=df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
plt.ylabel('28 Being able to guarantee the privacy of the customer',fontsize=20)
plt.xlabel('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['28 Being able to guarantee the privacy of the customer'],x=df['27 Empathy (readiness to assist with queries) towards the customers'])
plt.ylabel('28 Being able to guarantee the privacy of the customer',fontsize=20)
plt.xlabel('27 Empathy (readiness to assist with queries) towards the customers',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['30 Online shopping gives monetary benefit and discounts'],x=df['25 Convenient Payment methods'])
plt.ylabel('30 Online shopping gives monetary benefit and discounts',fontsize=20)
plt.xlabel('25 Convenient Payment methods',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['31 Enjoyment is derived from shopping online'],x=df['23 Loading and processing speed'])
plt.ylabel('31 Enjoyment is derived from shopping online',fontsize=20)
plt.xlabel('23 Loading and processing speed',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['31 Enjoyment is derived from shopping online'],x=df['25 Convenient Payment methods'])
plt.ylabel('31 Enjoyment is derived from shopping online',fontsize=20)
plt.xlabel('25 Convenient Payment methods',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['31 Enjoyment is derived from shopping online'],x=df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
plt.ylabel('31 Enjoyment is derived from shopping online',fontsize=20)
plt.xlabel('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['33 Return and replacement policy of the e-tailer is important for purchase decision'],x=df['32 Shopping online is convenient and flexible'])
plt.ylabel('33 Return and replacement policy of the e-tailer is important for purchase decision',fontsize=20)
plt.xlabel('32 Shopping online is convenient and flexible',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['38 User satisfaction cannot exist without trust'],x=df['22 Ease of navigation in website'])
plt.ylabel('38 User satisfaction cannot exist without trust',fontsize=20)
plt.xlabel('22 Ease of navigation in website',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['37 Net Benefit derived from shopping online can lead to users satisfaction'],x=df['35 Displaying quality Information on the website improves satisfaction of customers'])
plt.ylabel('37 Net Benefit derived from shopping online can lead to users satisfaction',fontsize=20)
plt.xlabel('35 Displaying quality Information on the website improves satisfaction of customers',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.set_palette('bright')
sns.swarmplot(y=df['40 Provision of complete and relevant product information'],x=df['35 Displaying quality Information on the website improves satisfaction of customers'])
plt.ylabel('40 Provision of complete and relevant product information',fontsize=20)
plt.xlabel('35 Displaying quality Information on the website improves satisfaction of customers',fontsize=20)
plt.yticks(fontsize=20)  
plt.xticks(fontsize=20)  
plt.show()
plt.tight_layout()
