# %%
import pandas as pd
import numpy as np
from selenium import webdriver 
import warnings
warnings.filterwarnings("ignore")
import time

from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException

# %% [markdown]
# # Q 1

# %%
dr=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr.get('http://www.naukri.com/')

# %%
search_skill=dr.find_element_by_class_name('suggestor-input ')
search_skill.send_keys("Data Analyst")

# %%
search_loc=dr.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[5]/div/div/div/input ')
search_loc.send_keys("Bangalore")

# %%
search_click=dr.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_click.click()

# %%
job_tag=dr.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[0:10]

print(len(job_tag))
# Out:
# 10

# %%
loc_tag=dr.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1] ")[0:10]
print(len(loc_tag))
# Out:
# 10

# %%
comp_tag=dr.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[0:10]
print(len(comp_tag))
# Out:
# 10

# %%
exp_tag=dr.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")[0:10]
print(len(exp_tag))
# Out:
# 10

# %% [markdown]
# # Q no. 1] DataFrame for Dat Analyst job by location Bangalore

# %%
jobs=[]
locs=[]
comps=[]
exps=[]

for i,l,c,e in zip(job_tag,loc_tag,comp_tag,exp_tag):
    jobs.append(i.text)
    locs.append(l.text)
    comps.append(c.text)
    exps.append(e.text)
    

df1=pd.DataFrame({'Job-Title':jobs,'Job-location':locs,'Company_name':comps,"Experience_required":exps})    
df1
# Out:
#                                        Job-Title  \
# 0                          Business Data Analyst
# 1      EY GDS Data Analyst-Finland based project
# 2              Data Analyst - Data and Analytics
# 3              Data Analyst - Data and Analytics
# 4                             Data Analyst (CSD)
# 5      Data Analyst - Data Science, 3 To 5 Years
# 6                Data Analyst / Business Analyst
# 7                                   Data Analyst
# 8  SAS/SQL - Healthcare Data Analyst - Bangalore
# 9     Business & Data Analyst - Alteryx (London)
#
#                                         Job-location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %%
dr.close()

# %% [markdown]
# # Q 2

# %%
dr2=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr2.get('http://www.naukri.com/')

# %%
search_skill1=dr2.find_element_by_class_name('suggestor-input ')
search_skill1.send_keys("Data Scientist")

# %%
search_loc1=dr2.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[5]/div/div/div/input ')
search_loc1.send_keys("Bangalore")

# %%
search_click1=dr2.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_click1.click()

# %%
job_title=dr2.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[0:10]

print(len(job_title))
# Out:
# 10

# %%
job_loc=dr2.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1] ")[0:10]
print(len(job_loc))
# Out:
# 10

# %%
company=dr2.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[0:10]
print(len(company))
# Out:
# 10

# %% [markdown]
# # Q no. 2 ] Datframe for Dat Scientist job by banglore location

# %%
job=[]
loc=[]
comp=[]


for i,l,c in zip(job_title,job_loc,company):
    job.append(i.text)
    loc.append(l.text)
    comp.append(c.text)
    

df2=pd.DataFrame({'Job-Title':job,'Job-location':loc,'Company_name':comp})    
df2
# Out:
#                                            Job-Title  \
# 0                              Senior Data Scientist
# 1                 Data Science - Engineering Manager
# 2                            AI Technologist Vacancy
# 3  Job Opening with Wipro For Data Scientist posi...
# 4     DATA Scientist with Fraud Analytics Experience
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                         Principal - Data Scientist
#
#                                         Job-location  \
# 0                        Mumbai, Bangalore/Bengaluru
# 1                 Noida, Mumbai, Bangalore/Bengaluru
# 2  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 3  Kolkata, Hyderabad/Secunderabad, Chennai, Bang...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %%
dr2.close()

# %% [markdown]
# # Q 3

# %%
dr3=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr3.get('http://www.naukri.com/')

# %%
search_skill3=dr3.find_element_by_class_name('suggestor-input ')
search_skill3.send_keys("Data Scientist")

# %%
search_click3=dr3.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_click3.click()

# %%
loc_filter=dr3.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[3]/label/i')
loc_filter.click()

# %%
time.sleep(5)
sal_filter=dr3.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")
sal_filter.click()

# %%
time.sleep(5)
tit=dr3.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[0:10]

print(len(tit))
# Out:
# 10

# %%
time.sleep(5)
location=dr3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1] ")[0:10]
print(len(location))
# Out:
# 10

# %%
time.sleep(5)
org=dr3.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[0:10]
print(len(org))
# Out:
# 10

# %%
time.sleep(5)
expert=dr3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")[0:10]
print(len(expert))
# Out:
# 10

# %% [markdown]
# # Q no. 3] DataFrame for Data scientist job by Delhi/NCR location and salary 3-6 lakhs

# %%
title=[]
locations=[]
orgs=[]
experts=[]
tit=dr3.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[0:10]
location=dr3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1] ")[0:10]
org=dr3.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[0:10]
expert=dr3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']")[0:10]
for t,l,o,e in zip(tit,location,org,expert):
    title.append(t.text)
    locations.append(l.text)
    orgs.append(o.text)
    experts.append(e.text)
    

df3=pd.DataFrame({'Job-Title':title,'Job-location':locations,'Company_name':orgs,"Experience_required":experts})    
df3
# Out:
#                                            Job-Title  \
# 0  Job Opening with Wipro For Data Scientist posi...
# 1               Data Scientist - Machine learning AI
# 2       Data Scientist -Machine Learning with Python
# 3                                     Data Scientist
# 4                     Data Scientist - MIND Infotech
# 5                     Data Scientist - MIND Infotech
# 6              Data Scientist - Predictive Analytics
# 7                Data Scientist - Internet Jobs - II
# 8  Machine Learning Engineer | Data Engineer | Da...
# 9  Hiring || Data Scientist || North Delhi || 5.5...
#
#                                         Job-location  \
# 0  Kolkata, Hyderabad/Secunderabad, Chennai, Bang...
# 1  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All ...
# 2    Noida, New Delhi, Gurgaon/Gurugram, Delhi / NCR
# 3        Pune, Gurgaon/Gurugram, Bangalore/Bengaluru
# 4                                              Noida
# 5                                              Noida
# ...

# %%
dr3.close()

# %% [markdown]
# # Q 4]

# %%
dr4=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr4.get('http://www.flipkart.com/')

# %%
time.sleep(5)
cancel_login=dr4.find_element_by_xpath("/html/body/div[2]/div/div/button")
cancel_login.click()

# %%
search_bar1=dr4.find_element_by_class_name("_3704LK")
search_bar1.send_keys('sunglasses')

# %%
search_but1=dr4.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_but1.click()

# %%
time.sleep(5)
brand_tag=dr4.find_elements_by_xpath("//div[@class='_2WkVRV']")
len(brand_tag)
# Out:
# 40

# %%
desc_tag=dr4.find_elements_by_xpath("//a[@class='IRpwTa']")
len(desc_tag)
# Out:
# 40

# %%
price_tag=dr4.find_elements_by_xpath("//div[@class='_30jeq3']")
len(price_tag)
# Out:
# 40

# %%
offer_tag=dr4.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
len(offer_tag)
# Out:
# 40

# %%
brand=[]
desc=[]
offer=[]
price=[]

for g in range(3): 
    brand_tag=dr4.find_elements_by_xpath("//div[@class='_2WkVRV']")
    desc_tag=dr4.find_elements_by_xpath("//a[@class='IRpwTa']")
    price_tag=dr4.find_elements_by_xpath("//div[@class='_30jeq3']")
    offer_tag=dr4.find_elements_by_xpath("//div[@class='_3Ay6Sb']")

    for i,j,k,l in zip(brand_tag,desc_tag,price_tag,offer_tag):
        if len(brand)<100:
            brand.append(i.text)
            desc.append(j.text)
            price.append(k.text)
            offer.append(l.text)
        else:
            break
         
    next_but=dr4.find_elements_by_xpath("//a[@class='_1LKTO3']")
    next_but[-1].click()   
    time.sleep(10)

# %% [markdown]
# # Q no. 4] DtaFrame for sunglasses from flipkart

# %%
df4=pd.DataFrame({'Brand':brand,'Product_Description':desc,'Price':price,"Offer ":offer},index=range(1,101))    
df4
# Out:
#               Brand                                Product_Description Price  \
# 1      Singco India  Gradient, Toughened Glass Lens, UV Protection ...  ₹664
# 2    ROZZETTA CRAFT         UV Protection Round Sunglasses (Free Size)  ₹399
# 3              SRPM             UV Protection Wayfarer Sunglasses (50)  ₹211
# 4          Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹799
# 5            PIRASO              UV Protection Aviator Sunglasses (54)  ₹249
# ..              ...                                                ...   ...
# 96        ROYAL SON  UV Protection, Gradient Butterfly, Over-sized ...  ₹699
# 97     CRYSTAL CART  Polarized, UV Protection Retro Square Sunglass...  ₹319
# 98         Fastrack              UV Protection Aviator Sunglasses (57)  ₹635
# 99            GHAWK   UV Protection Rectangular Sunglasses (Free Size)  ₹299
# 100          AISLIN       UV Protection, Gradient Oval Sunglasses (58)  ₹498
#
#       Offer
# 1    77% off
# 2    85% off
# ...

# %%
dr4.close()

# %% [markdown]
# # Q 5]

# %%
dr5=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
# The below website link have provided to me by sme , In reply of raised ticket

# %%
dr5.get('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART')

# %%
time.sleep(5)
summ_tag=dr5.find_elements_by_xpath("//p[@class='_2-N8zT']")
rev_tag=dr5.find_elements_by_xpath("//div[@class='t-ZTKy']")
rat_tag=dr5.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")

# %%
print(len(summ_tag),len(rat_tag),len(rev_tag))
# Out:
# 10 10 10

# %%
len(summ_tag)==len(rat_tag)==len(rev_tag)
# Out:
# True

# %%
summary=[]
rating=[]
review=[]


for g in range(11): 
    summ_tag=dr5.find_elements_by_xpath("//p[@class='_2-N8zT']")
    rev_tag=dr5.find_elements_by_xpath("//div[@class='t-ZTKy']")
    rat_tag=dr5.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    for s,rv,r in zip(summ_tag,rev_tag,rat_tag):
        if len(summary)<100:
            summary.append(s.text)
            review.append(rv.text)
            rating.append(r.text)
            
    nxt_but5=dr5.find_elements_by_xpath("//a[@class='_1LKTO3']")
    nxt_but5[-1].click()
    time.sleep(10)

# %%
len(rating)==len(summary)==len(review)
# Out:
# True

# %% [markdown]
# # Q no. 5] Dataframe for iphone 11 review from flipkart

# %%
df5=pd.DataFrame({'Review_summary':summary,'Full_Review':review,'Rating':rating})
df5
# Out:
#            Review_summary                                        Full_Review  \
# 0          Simply awesome  Really satisfied with the Product I received.....
# 1     Best in the market!  Great iPhone very snappy experience as apple k...
# 2        Perfect product!  Amazing phone with great cameras and better ba...
# 3       Worth every penny  Previously I was using one plus 3t it was a gr...
# 4      Highly recommended  What a camera .....just awesome ..you can feel...
# ..                    ...                                                ...
# 95      Worth every penny  Undoubtedly Iphone 11 is the most successful m...
# 96    Best in the market!  Don’t expect much from front camera… especiall...
# 97              Fabulous!  I purchased the iPhone 11 a month back. I must...
# 98  Mind-blowing purchase  Absolutely powerful gadget. Loved it’s look! S...
# 99                Awesome  Can’t beat the software and hardware integrati...
#
#    Rating
# 0       5
# 1       5
# ...

# %%
dr5.close()

# %% [markdown]
# # Q 6]

# %%
dr6=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr6.get('https://www.flipkart.com/')

# %%
time.sleep(5)
cancel_login6=dr6.find_element_by_xpath("/html/body/div[2]/div/div/button")
cancel_login6.click()

# %%
search_bar6=dr6.find_element_by_class_name("_3704LK")
search_bar6.send_keys('sneakers')

# %%
search_but6=dr6.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_but6.click()

# %%
time.sleep(5)
brand_tag6=dr6.find_elements_by_xpath("//div[@class='_2B099V']")
pr_tag6=dr6.find_elements_by_xpath("//div[@class='_30jeq3']")
off_tag6=dr6.find_elements_by_xpath("//div[@class='_3Ay6Sb']")

# %%
sn_brand=[]
desc=[]
pric=[]
off=[]
for g in range(3):
    brand_tag6=dr6.find_elements_by_xpath("//div[@class='_2B099V']")
    pr_tag6=dr6.find_elements_by_xpath("//div[@class='_30jeq3']")
    off_tag6=dr6.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
    for i,p,n in zip(brand_tag6,pr_tag6,off_tag6):
        if len(sn_brand)<100:
            sn_brand.append(i.text.split('\n')[0])
            desc.append(i.text.split('\n')[1])
            pric.append(p.text)
            off.append(n.text)
    nxt6=dr6.find_elements_by_xpath("//a[@class='_1LKTO3']")        
    nxt6[-1].click()
    time.sleep(5)

# %%
len(sn_brand)==len(desc)==len(pric)==len(off)
# Out:
# True

# %% [markdown]
# # Q no.6] Data frame for sneakers data from flipkart

# %%
df6=pd.DataFrame({'Brand':sn_brand,'Product_Description':desc,"Price":pric,"offer":off})
df6
# Out:
#               Brand                                Product_Description  \
# 0           NAUTICA         Nautica Men Blue Sneakers Sneakers For Men
# 1           NAUTICA                                   Sneakers For Men
# 2          Magnolia                                   Sneakers For Men
# 3            BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 4            Layasa                                   Sneakers For Men
# ..              ...                                                ...
# 95           Kraasa                              Boom Sneakers For Men
# 96  U.S. POLO ASSN.                                   Sneakers For Men
# 97   luxury fashion         Fashionable sneaker shoes Sneakers For Men
# 98           revord                                   Sneakers For Men
# 99           Chevit  Unique & Perfect Collection Combo Pack of 02 S...
#
#      Price    offer
# 0   ₹1,169  74% off
# 1   ₹1,324  75% off
# 2     ₹374  62% off
# 3     ₹299  76% off
# ...

# %%
dr6.close()

# %% [markdown]
# # Q 7]

# %%
dr7=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
time.sleep(5)
dr7.get("http://www.myntra.com/shoes")

# %%
time.sleep(5)
sel_price7=dr7.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
sel_price7.click()

# %%
sel_color7=dr7.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
sel_color7.click()

# %%
brandtag=dr7.find_elements_by_xpath("//h3[@class='product-brand']")
len(brandtag)
# Out:
# 50

# %%
desctag=dr7.find_elements_by_xpath("//h4[@class='product-product']")
len(desctag)
# Out:
# 50

# %%
pricetag=dr7.find_elements_by_xpath("//div[@class='product-price']")
len(pricetag)
# Out:
# 50

# %%
brand_list=[]
desc_list=[]
price_list=[]

for g in range(2):
    brandtag=dr7.find_elements_by_xpath("//h3[@class='product-brand']")
    desctag=dr7.find_elements_by_xpath("//h4[@class='product-product']")
    pricetag=dr7.find_elements_by_xpath("//div[@class='product-price']")
    
    for b,d,p in zip(brandtag,desctag,pricetag):
        if len(brand_list)<100:
            br=b.text
            brand_list.append(br)
            des=d.text
            desc_list.append(des)
            pr=p.text.split("Rs")[1].replace('.',"Rs")
            price_list.append(pr)
    time.sleep(5)
    next_button=dr7.find_element_by_class_name('pagination-next')
    next_button.click()
    time.sleep(10)

# %%
len(brand_list)==len(desc_list)==len(price_list)
# Out:
# True

# %% [markdown]
# # Q no.7] Dataframe for shoes from myntra scraped data

# %%
df7=pd.DataFrame({'Product_Brand':brand_list,"Product_description":desc_list,"Price":price_list})
df7
# Out:
#       Product_Brand           Product_description     Price
# 0              Nike          Men Basketball Shoes  Rs 15635
# 1          Red Tape             Men Walking Shoes   Rs 1469
# 2          Red Tape             Men Running Shoes   Rs 1649
# 3            ADIDAS  Men FleeceWalk Walking Shoes   Rs 2639
# 4        Eego Italy            Men Trekking Shoes    Rs 987
# ..              ...                           ...       ...
# 95      Sir Corbett             Semi-Formal Shoes    Rs 914
# 96         Skechers   Women GO Walk Ultra Walking   Rs 4499
# 97  U.S. Polo Assn.  Men LEBRON 2.0 Walking Shoes   Rs 2999
# 98      one8 x PUMA  Unisex SoftRide Rift Walking   Rs 3899
# 99         Provogue      Men Solid Formal Loafers    Rs 879
#
# [100 rows x 3 columns]

# %%
dr7.close()

# %% [markdown]
# # Q 8]

# %%
dr8=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
dr8.get("https://www.amazon.in/")

# %%
time.sleep(7)    
search_bar8=dr8.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input ")
search_bar8.send_keys('Laptop')

# %%
search_but8=dr8.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_but8.click()

# %%
time.sleep(7)    
try:
    path8=("/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[4]/li[13]/span/a")
    sel_cpu8=dr8.find_element_by_xpath(path8) 
    sel_cpu8.click() #/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[13]/span/a/div/label/i
except StaleElementReferenceExceptions as e:
    print("Exception Raised :",e)
    path8=("/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[4]/li[13]/span/a/div/label/i")
    sel_cpu8=dr8.find_element_by_xpath(path8) 
    sel_cpu8.click()

# %%
# trials for scraping rating of laptop
time.sleep(7)    
rat_tag8=dr8.find_elements_by_xpath("//span[@class='a-icon-alt']")
rating8=[]
for i in rat_tag8:
    rating8.append(i.text)

# %%
tit8=[]

pri8=[]
#for g in range(2):
title8=dr8.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
price8=dr8.find_elements_by_xpath("//span[@class='a-price-whole']")
for t,p in zip(title8,price8):
    if len(tit8)<10:
        tit8.append(t.text)
        pri8.append(p.text)

# %% [markdown]
# * I have not scrape data for rating due to not getting suitable class, which was also  repied by sme in Raised ticket

# %%
len(tit8)==len(pri8)
# Out:
# True

# %% [markdown]
# # Qno. 8] Dataframe for laptop info in amazon

# %%
df8=pd.DataFrame({'Title':tit8,"Price":pri8})
df8
# Out:
#                                                Title     Price
# 0  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    93,100
# 1  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...    83,990
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...    57,490
# 3  Lenovo IdeaPad 5 Pro 11th Gen Intel Core i7 14...    74,511
# 4  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    86,990
# 5  ASUS Vivobook X515JA-EJ701WS Intel Core I7-106...    57,290
# 6  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    84,490
# 7  HP Pavilion 14 11th Gen Intel Core i7 16GB/1TB...    93,000
# 8  HP Victus 11th Gen Intel Core i7-11800H 16.1-i...  1,20,062
# 9  ASUS TUF Gaming F15 (2021) 15.6-inch (39.62 cm...    85,990

# %%
dr8.close()

# %% [markdown]
# # Q 9]

# %%
dr9=webdriver.Chrome('C:\web driver\chromedriver.exe')

# %%
time.sleep(5)
dr9.get("http://www.ambitionbox.com/")

# %%
time.sleep(5)
job_but9=dr9.find_element_by_xpath("/html/body/div[1]/nav/nav/a[6]")
job_but9.click()

# %%
path91="/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input"
search_bar9=dr9.find_element_by_xpath(path91)
search_bar9.send_keys("Data Scientist")

# %%
path92="/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button/span"
search_but9=dr9.find_element_by_xpath(path92)
search_but9.click()

# %%
time.sleep(5)
loct_but9=dr9.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/p")
loct_but9.click()

# %%
time.sleep(5)
path93="/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input"
search_loc9=dr9.find_element_by_xpath(path93)
search_loc9.send_keys("Noida")

# %%
time.sleep(5)
path94="/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label"
noida_but9=dr9.find_element_by_xpath(path94)
noida_but9.click()

# %%
time.sleep(5)

tit9=[]
day9=[]
rat9=[]
comp9=[]
title9=dr9.find_elements_by_xpath("//a[@class='title noclick']")
day_tag9=dr9.find_elements_by_xpath("//span[@class='body-small-l'][1]")
rating9=dr9.find_elements_by_xpath("//span[@class='body-small']")
comp_tag9=dr9.find_elements_by_xpath("//p[@class='company body-medium']")
for i,d,r,c in zip(title9,day_tag9,rating9,comp_tag9):
    tit9.append(i.text)
    day9.append(d.text)
    rat9.append(r.text)
    comp9.append(c.text)

# %%
len(tit9)==len(day9)==len(rat9)==len(comp9)
# Out:
# True

# %% [markdown]
# # Q no. 9] Dataframe for job adds in ambiton box for Noida

# %% [markdown]
# * Be patient at this satge sometime it generates emty dataframe retry again !

# %%
df9=pd.DataFrame({'Job Title':tit9,"Company Name":comp9,'Rating of company':rat9,"Number of days ago job posted ":day9})
df9
# Out:
#                                       Job Title  \
# 0                                Data Scientist
# 1                         Senior Data Scientist
# 2  Data Scientist -Machine Learning with Python
# 3                          Data Scientist - OIP
# 4                    Data Scientist- AI/ML- R&D
# 5            Data Science - Lead Data Scientist
# 6     Data Scientist (Python) Immediate Joiners
# 7     Data Scientist - Associate Vice President
# 8                Data Scientist - MIND Infotech
# 9                                Data Scientist
#
#                                      Company Name Rating of company  \
# 0                   GENPACT India Private Limited               4.0
# 1  Optum Global Solutions (India) Private Limited               4.2
# 2                   GENPACT India Private Limited               4.0
# 3                        Hcl Technologies Limited               3.9
# 4                EXL Services.com ( I ) Pvt. Ltd.               3.9
# ...

# %%
dr9.close()

# %% [markdown]
# #  Q 10]

# %%
dr10=webdriver.Chrome("C:\web driver\chromedriver.exe")

# %%
dr10.get("https://www.ambitionbox.com/")

# %%
salary_tab=dr10.find_element_by_xpath("/html/body/div[1]/nav/nav/a[4]")
salary_tab.click()

# %%
search_bar10=dr10.find_element_by_xpath("/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input")
search_bar10.send_keys("Data Scientist")

# %%
time.sleep(5)
try:
    ds=dr10.find_element_by_xpath("//div[@class='top-row'][1]")
    ds.click()

except ElementNotInteractableException as e: 
    print("Exception error",e)
    ds=dr10.find_element_by_xpath('/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div')
    ds.click()

# %%
comp10=[]
totsal10=[]
exp10=[]
avg10=[]
min10=[]
max10=[]

comp_tag10=dr10.find_elements_by_xpath("//div[@class='name']/a")
totsal_tag10=dr10.find_elements_by_xpath("//div[@class='name']/span")
exp_tag10=dr10.find_elements_by_xpath("//div[@class='salaries sbold-list-header']")
avg_tag10=dr10.find_elements_by_xpath("//p[@class='averageCtc']")
min_tag10=dr10.find_elements_by_xpath("//div[@class='value body-medium'][1]")
max_tag10=dr10.find_elements_by_xpath("//div[@class='value body-medium'][2]")

for c,t,e,a,mn,mx in zip(comp_tag10,totsal_tag10,exp_tag10,avg_tag10,min_tag10,max_tag10):
    comp10.append(c.text)
    totsal10.append(t.text)
    exp10.append(e.text.split('\n')[-1])
    avg10.append(a.text)
    min10.append(mn.text)
    max10.append(mx.text)

# %% [markdown]
# # Q no. 10] DataFrame for Data Scientist salary by organization or firm

# %%
df10=pd.DataFrame({"Company Name":comp10,"Total Salary Record":totsal10,"Experience Required":exp10,
                "Average Salary":avg10,"Minimum Salary":min10,"Maximum Salary":max10})

df10
# Out:
#         Company Name   Total Salary Record Experience Required Average Salary  \
# 0            Walmart  based on 12 salaries           3 yrs exp        ₹ 30.2L
# 1           Ab Inbev  based on 33 salaries         3-4 yrs exp        ₹ 20.6L
# 2   American Express  based on 10 salaries           4 yrs exp        ₹ 19.9L
# 3                 ZS  based on 15 salaries           2 yrs exp        ₹ 16.7L
# 4              Optum  based on 33 salaries         3-4 yrs exp        ₹ 16.1L
# 5       Reliance Jio  based on 21 salaries         3-4 yrs exp        ₹ 15.7L
# 6  Fractal Analytics  based on 83 salaries         2-4 yrs exp        ₹ 15.4L
# 7    Tiger Analytics  based on 50 salaries         2-4 yrs exp        ₹ 14.8L
# 8       UnitedHealth  based on 57 salaries         2-4 yrs exp        ₹ 14.0L
# 9        EXL Service  based on 10 salaries           4 yrs exp        ₹ 13.3L
#
#   Minimum Salary Maximum Salary
# 0        ₹ 25.0L        ₹ 36.0L
# 1        ₹ 15.0L        ₹ 25.5L
# ...

# %%
dr10.close()
